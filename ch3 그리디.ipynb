# %% [markdown]
# # 그리디

# %% [markdown]
# 탐욕법, 욕심쟁이 알고리즘

# %% [markdown]
# 어떠한 문제가 있을 때 무식하게 탐욕적(현재 상황에 잠금 당장 좋은 것만 고르는 방법)으로 문제를 푸는 알고리즘

# %% [markdown]
# '가장 큰 순서대로', '가장 작은 순서대로'와 같은 기준을 알게 모르게 제시
# 그렇기에 정렬과 짝지어 많이 나옴

# %% [markdown]
# ## 예제 3-1 거스름돈

# %% [markdown]
# 당신은 음식점의 계산을 도와주는 점원이다. 카운터에는 거스름돈으로 사용할 500원,100원,50원,10원 동전이 무한히 존재한다고 가정
# 손님에게 거슬러 줘야 할 돈이 N원일 때 거슬러 줘야 할 동전의 최소의 개수를 구해라.
# 단,거슬러 줘야 할 돈 N은 항상 10의 배수

# %% [markdown]
# - N=1260

# %%
n=1260
count=0
coin=[500,100,50,10]
for i in coin:
    count+=n//i
    n%=i
print(count)
# Out:
# 6

# %% [markdown]
# ## 큰 수의 법칙

# %% [markdown]
# 다양한 수로 이루어진 배열이 있을 때 주어진 수들을 M번 더하여 가장 큰 수를 만드는 법칙
# 단, 배열의 특정한 인덱스에 해당하는 수가 연속해서 K번을 초과하여 더해질 수 없는 것이 특징
# 같은 수여도 인덱스가 다르면 다른걸로 인정

# %% [markdown]
# - 입력 조건
# 첫째 줄에 N(2<=N<=1000),M(1<=M<=10000),K(1<=K<=10000)의 자연수가 주어지며, 각 자연수는 공백으로 구분
# 둘째 줄에 N개의 자연수가 주어짐, 각 자연수는 공백으로 구분, 각각의 자연수는 1 이상 10000이하의 수
# K<=M

# %% [markdown]
# - 출력 조건
# 합을 출력

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n,m,k=map(int,input().split())
# Out:
# 5 8 3

# %%
data=list(map(int,input().split()))
# Out:
# 2 4 5 4 6

# %%
data.sort()
first=data[n-1]
second=data[n-2]

count=int(m/(k+1))*k
count+=m%(k+1)

result=0
result+= (count)*first
result+=(m-count)*second

print(result)
# Out:
# 46
